# %%
# !pip install pattern
# Out:
# ...
#     100% |████████████████████████████████| 24.6MB 46kB/s eta 0:00:011
# ...
#   Running setup.py bdist_wheel for pattern ... done
#   Stored in directory: /home/set92/.cache/pip/wheels/88/c3/56/c85103e2876796af4a892df2367a879007d36d74511bf47d42
# Successfully built pattern
# ...

# %%
#Necesario ejecutar con python2
from pattern.web import Twitter
import os
import io

t = Twitter()
i = None
with io.open('dataset','w',encoding='utf8') as f: 
    for j in range(3):
        for tweet in t.search('Machine Learning', start=i, count=100):
            print(tweet.text + " *-* " + tweet.author + os.linesep)
            print 
            f.write(tweet.text + " *-* " + tweet.author + os.linesep)

            i = tweet.id
# Out:
# Splunk Brings #MachineLearning to #DataAnalytics - https://t.co/FeBWPlJBo6 #Analytics #BigData #ArtificialIntelligence #DeepLearning *-* OttLegalRebels
#
#
# Machine Learning en el ámbito empresarial. Infografía de ICEMD @icemd #IoT https://t.co/W7OblCuTj4 *-* gerardoraido
#
#
# watson-machine-learning-client 0.0.16a0: Watson Machine Lea... https://t.co/MSAHmBl023 *-* pypi_updates2
#
#
# RT @DoctorJosh: We're hiring! Open tenure-track CS faculty position in Data Science/Machine Learning at the University of Vermont. https://… *-* stenichele
#
#
# Jose Ruíz, @paradigmate " en los próximos años solo sobrevivirán las compañías que pueden reinventarse con la IA"… https://t.co/v4YgkOKi3P *-* GlobbIT_ES
#
#
# RT @AlfonsoRomay: Hoy escribo en el blog de @uxtbe sobre retos de diseño de #UX en entornos de #MachineLearning https://t.co/W6BDnmScVH *-* ayinparrot
#
#
# RT @Amrapali_c: Great!
# Startups that would be successful!!  https://t.co/ckSBCozCxH
# ...
