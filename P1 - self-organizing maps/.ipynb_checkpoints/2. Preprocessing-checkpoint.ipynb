# %%
import pandas as pd
import numpy as np

import timeit
import nltk

import scipy.spatial.distance as distance

# %%
df = pd.read_csv('datasetG.txt', sep="\n", names=['p1'])

# %%
# Se separan las palabras, creando una lista de palabras en vez de un string para luego calcular el vector
df['p1'] = pd.Series([nltk.word_tokenize(x[0]) for x in df.itertuples(index=False)], index=df.index)

# %%
#Lo hice en un inicio para quitar : , ... pero luego me acorde que son punctuation, no stopwords, asi que no sirve
#Quita he, to...print stopwords si se quieren ver todas
from nltk.corpus import stopwords
stopwords = nltk.corpus.stopwords.words('english')
df['p1'] = df['p1'].apply(lambda x: [item for item in x if item not in stopwords])

# %% [raw]
# #Cogemos la 1ra mitad del dataset y para la columna 1
# df = df_aux.iloc[:147]
# #Cogemos las 150 empezando desde atras, reseteamos el index para que empiece desde 0, y nombramos con algo entendible
# df_aux = df_aux[-150:]
# df_aux = df_aux.reset_index()
# df_aux.columns = ['index','p2']
# df['p2'] = df_aux['p2']

# %% [raw]
# #Tokenizer
#
# df2 = df.copy()
# start_time = timeit.default_timer()
# df2['p1'] = pd.Series([nltk.word_tokenize(x[0]) for x in df.itertuples(index=False)], index=df.index)
# df2['p2'] = pd.Series([nltk.word_tokenize(x[1]) for x in df.itertuples(index=False)], index=df.index)
# df2["avgQ1Q2"] = -1.0
# print(timeit.default_timer() - start_time)

# %%
#Word2Vec
import gensim
start_time = timeit.default_timer()

model = gensim.models.KeyedVectors.load('../../quora/data/GoogleNews-vectors-negative300.bin.gz', mmap=None)

print(timeit.default_timer() - start_time)
# Out:
# Using TensorFlow backend.
# 42.31836415800001

# %%
def feature_vector(tweet, num_features, model):
    #print(tweet)
    words_not_founded = set()
    featureVec = np.zeros((num_features,), dtype="float32")
    vecTweet = {}
    
    for word in tweet:
        if word in model:
            featureVec = np.add(featureVec, model[word])
            vecTweet.update({word : featureVec})
            
        else:
            words_not_founded.add(word)
    #print(words_not_founded)
    return vecTweet

#feature_vector(df['p1'][0], 300, model)

# %%
df['vector'] = [feature_vector(row[1], 300, model) for row in df.itertuples()]

# %%
#recorrer dict df[vector] y coger los values

# %%
from sklearn.manifold import TSNE
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

iris = load_iris()
X_tsne = TSNE(learning_rate=100).fit_transform(iris.data)
X_pca = PCA().fit_transform(iris.data)

# %%
# %pylab inline

figure(figsize=(10, 5))
subplot(121)
scatter(X_tsne[:, 0], X_tsne[:, 1], c=iris.target)
subplot(122)
scatter(X_pca[:, 0], X_pca[:, 1], c=iris.target)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df['vector']
# Out:
# 0     {'east': [-0.0305466, -0.0396537, 0.031685, -0...
# 1     {'oracles': [0.127934, -0.0222069, 0.0201119, ...
# 2     {'want': [0.0599332, 0.0650703, 0.0503011, 0.0...
# 3     {'ich': [0.0380955, 0.127525, -0.000462262, 0....
# 4     {'cto': [0.0709476, -0.0577481, -0.0747975, -0...
# 5     {'building': [-0.00444988, 0.0130159, 0.024696...
# 6     {'best': [-0.056807, 0.00983198, 0.128471, 0.0...
# 7     {'5': [0.0556331, -0.0246206, 0.0326697, 0.046...
# 8     {'derive': [0.0603189, -0.0447527, -0.0635618,...
# 9     {'google': [0.0361184, -0.0734877, 0.00570702,...
# 10    {'google': [0.0361184, -0.0734877, 0.00570702,...
# 11    {'great': [0.0306035, 0.0886877, -0.0121269, 0...
# 12    {'best': [-0.056807, 0.00983198, 0.128471, 0.0...
# 13    {'machine': [0.0971242, -0.00838715, 0.0110284...
# 14    {'build': [-0.0582157, 0.0879176, 0.015742, 0....
# 15    {'machine': [0.0971242, -0.00838715, 0.0110284...
# 16    {'mathematics': [0.0769223, -0.0138045, 0.0663...
# 17    {'3': [0.0547499, -0.0398393, 0.0160755, 0.050...
# 18    {'chairman': [0.00369831, -0.0539994, 0.004547...
# 19    {'machine': [0.0971242, -0.00838715, 0.0110284...
# 20    {'build': [-0.0582157, 0.0879176, 0.015742, 0....
# 21    {'execs': [0.0359734, 0.0730624, -0.0694371, 0...
# 22    {'pas': [0.0471727, -0.0141208, 0.0418968, 0.0...
# 23    {'possible': [-0.0376749, 0.0519818, 0.0206258...
# 24    {'introduction': [-0.0331618, 0.038217, -0.097...
# 25    {'machine': [0.0971242, -0.00838715, 0.0110284...
# 26    {'chairman': [0.00369831, -0.0539994, 0.004547...
# 27    {'tech': [0.0434898, 0.0569631, -0.0150935, 0....
# 28    {'5': [0.0556331, -0.0246206, 0.0326697, 0.046...
# 29    {'ai': [-0.0426236, 0.0908068, -0.0162927, 0.0...
#                             ...
# 69    {'machine': [0.0971242, -0.00838715, 0.0110284...
# 70    {'python': [0.0731009, 0.0326895, -0.107592, 0...
# 71    {'research': [-0.0468489, -0.018312, -0.024539...
# 72    {'open': [-0.0159434, -0.0318869, 0.0551334, 0...
# 73    {'pistes': [0.024264, 0.0210368, 0.0504404, -0...
# 74    {'roi': [0.0718123, -0.084731, 0.027927, 0.014...
# 75    {'machine': [0.0971242, -0.00838715, 0.0110284...
# 76    {'blog': [0.0343191, -0.00477737, -0.0798699, ...
# 77    {'top': [-0.0496964, 0.0092197, 0.0526197, -0....
# 78    {'machine': [0.0971242, -0.00838715, 0.0110284...
# 79    {'brings': [0.039606, -0.0223933, 0.0389375, -...
# 80    {'machine': [0.0971242, -0.00838715, 0.0110284...
# 81    {'3q': [-0.0244082, 0.000759454, -0.0528316, 0...
# 82    {'use': [0.0540498, -0.0627071, 0.0320555, 0.0...
# 83    {'iot': [0.00706656, -0.0325367, 0.00849004, 0...
# 84    {'razor': [-0.0145707, 0.0243837, 0.0767194, 0...
# 85    {'generalized': [0.0444161, -0.0660825, -0.054...
# 86    {'machine': [0.0971242, -0.00838715, 0.0110284...
# 87    {'meet': [-0.144437, 0.0672513, 0.0317151, 0.0...
# 88    {'bing': [-0.025154, 0.0281327, 0.0179553, 0.0...
# 89    {'want': [0.0599332, 0.0650703, 0.0503011, 0.0...
# 90    {'machine': [0.0971242, -0.00838715, 0.0110284...
# 91    {'java': [-0.0413184, -0.0579646, -0.113551, 0...
# 92    {'machine': [0.0971242, -0.00838715, 0.0110284...
# 93    {'essential': [-0.000471094, -0.085265, -0.035...
# 94    {'annotated': [-0.0125148, -0.068644, -0.00473...
# 95    {'intelligence': [0.0160533, -0.00875635, -0.0...
# 96    {'7': [0.0640333, -0.0412969, -0.00449509, 0.0...
# 97    {'executive': [-0.0129297, -0.0845971, -0.0118...
# 98    {'machine': [0.0971242, -0.00838715, 0.0110284...
# Name: vector, Length: 99, dtype: object

# %%
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2).fit(df['vector'])
X_embedded.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f88f2e828ea0> in <module>()
#       1 from sklearn.manifold import TSNE
# ----> 2 X_embedded = TSNE(n_components=2).fit(df['vector'])
#       3 X_embedded.shape
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in fit(self, X, y)
#     897             or 'coo'.
#     898         """
# --> 899         self.fit_transform(X)
#     900         return self
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in fit_transform(self, X, y)
#     882             Embedding of the training data in low-dimensional space.
#     883         """
# --> 884         embedding = self._fit(X)
#     885         self.embedding_ = embedding
#     886         return self.embedding_
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in _fit(self, X, skip_num_points)
#     705         else:
#     706             X = check_array(X, accept_sparse=['csr', 'csc', 'coo'],
# --> 707                             dtype=np.float64)
#     708         random_state = check_random_state(self.random_state)
#     709
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     380                                       force_all_finite)
#     381     else:
# --> 382         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     383
#     384         if ensure_2d:
#
# TypeError: float() argument must be a string or a number, not 'dict'
